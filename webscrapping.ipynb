# %%
import requests

url = 'https://www.nytimes.com/2023/12/13/podcasts/cop-gaza-un.html'
response = requests.get(url)

if response.status_code == 200:
    html_content = response.text
else:
    print("Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Failed to retrieve the page. Status code: {response.status_code}

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_content, 'html.parser')
# Extract data using soup.find(), soup.find_all(), etc.

# %%
soup.find_all()
# Out:
# [<html dir="ltr" lang="en" style="padding: 0; margin: 0;"><head prefix="og: http://ogp.me/ns#"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-45fb25f19e8b12dc.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-d63dccccd7532047.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-85d32558dbb194f2.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack" rel="preload"/><link as="style" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-5cf6a3e5274bdb4b.webpack" rel="preload"/><link href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-5cf6a3e5274bdb4b.webpack" id="ans-frontend-main-css" rel="stylesheet" type="text/css"/><script type="text/javascript">function reportToAndroid(){if(0!==assetErrs.length){var e=window.QuoraAndroid;e&&e.reportBrowserAssetLoadErrors&&e.reportBrowserAssetLoadErrors(assetErrs)}}var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),r=new XMLHttpRequest;r.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),r.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),r.setRequestHeader("Accept","*/*"),r.send(e.replace(/%20/g,"+"))}},0),setTimeout(function(){reportToAndroid()},500)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};
#  </script><script id="entryjs_wrapper" type="text/javascript">
#          window.__entryChunkLoaded = false;
#          window.__onEntryLoaded = [];
#          window.executeAfterEntryjsLoaded = function (callback) {
#              if (window.__entryChunkLoaded) {
#                  callback();
#              } else {
#                  window.__onEntryLoaded.push(callback);
#              }
#          }
#      </script><script type="text/javascript">window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"0":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-0-27-8f1f52608d2109b5.webpack","common":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack","common-LoggedOut":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack","common-Mweb":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-Mweb-27-a2a9baed98b578b2.webpack","common-NativeApp":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-NativeApp-27-5ac0f4987a77a6e9.webpack","common-secondary":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-secondary-27-5d3f8a77b917c3f6.webpack","component-ActivationDeckInner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ActivationDeckInner-27-108638bff8c6fc4a.webpack","component-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack","component-AdCTABanner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-fc5f333bd1dbb044.webpack","component-AdminTools-profile":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-8482e48a7b12f267.webpack","component-AnnouncementBundle":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnnouncementBundle-27-93eeec7919d4d58a.webpack","component-AnswerFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerFooter-27-3930dae346f85416.webpack","component-AnswerPageFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-7083d7cb98258866.webpack","component-CaptchaPopper":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CaptchaPopper-27-9abe5b6edbdac191.webpack","component-CollapseAnswerSection":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CollapseAnswerSection-27-9b5e942a1b461e1c.webpack","component-CommentAd":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CommentAd-27-410023ea1055f83a.webpack","component-Comments":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-4611281ba67142a5.webpack","component-FeedSwitcher":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FeedSwitcher-27-e01ab61d19a895f4.webpack","component-FirstFeedScrollPrompt":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FirstFeedScrollPrompt-27-22169656b2cee358.webpack","component-GenericRightRail-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-GenericRightRail-Ad-27-c1feaad37682332d.webpack","component-Hovercards":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-849647e7e4f247bc.webpack","component-ImageViewer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ImageViewer-27-75f2fc0682e7421f.webpack","component-LightweightSurvey":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LightweightSurvey-27-a66e1c8cee192e1d.webpack","component-LiveStatsBundle":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LiveStatsBundle-27-a089ab62a894065a.webpack","component-LoggedOutFeed":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LoggedOutFeed-27-f31f207a3c91f459.webpack","component-Login":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Login-27-ea4f62d26c121889.webpack","component-MobileLookup":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-956821c6311b13ad.webpack","component-Modals-AdsConsumer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-6a28ee082ea21a21.webpack","component-Modals-AdsManager":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-f9a883c2ecd8eed3.webpack","component-Modals-AskQuestion":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-2630df9808f9e392.webpac ...
#  var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
#  window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-QuestionPageLoadable","component-Ad","component-QuestionPage","common-LoggedOut"]);</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "7d51d25ea07a98ba1a319b9b93cb8365", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "isMobileAppPrefetched": false, "topLevelNid": 0, "react_console_log_perf_info": false, "subdomainSuffix": "quora.com", "windowId": "react_afvxlnopeppkuxmz", "rootClsKey": "QuestionPage", "rootQueryVariables": {"questionSlug": "Is-it-possible-to-forge-a-Coursera-course-completion-certificate", "questionSlugEncoded": "Is-it-possible-to-forge-a-Coursera-course-completion-certificate", "redirectedQid": 0, "topAid": null, "first": 50, "forceScoreVersion": null}, "rootProps": {}, "pageWrapperQueryVariables": {}, "inlineQueryHashes": {"27a81ba144b4201b299bc86442d67c6bb37896ff0e163465e59b90ee95b98604": true, "3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b": true, "2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083": true}, "pageShellInfo": null, "shouldServerRender": false, "hasIndicator": true, "isServiceWorkerConstructed": false};</script><script type="text/javascript">function getLoggingUrl(){var e="/ajax/page_bounce_POST";return"quora.com"==window.ansFrontendGlobals.earlySettings.subdomainSuffix?"https://log.quora.com/ajax/page_bounce_POST":e}function logPageBounce(e){if(window.isReactPage&&!window.reportedPageLoadBounce&&!window.ansFrontendGlobals.earlySettings.isMobileAppPrefetched&&!window.ansFrontendGlobals.earlySettings.isPrefetchedPage){window.reportedPageLoadBounce=!0;var n=window.ansFrontendGlobals.earlySettings.windowId,o={url:window.location.href,windowId:n,wasViewed:window.wasViewed};if(window.performance&&window.performance.timing){var a=window.performance.timing.navigationStart;a&&(o.unloadTime=Date.now()-a,o.cause=e)}var i=getLoggingUrl(),t=window.ansFrontendGlobals.earlySettings.formkey,d=[{category:"unload_before_page_ready",data:o,time:1e3*Date.now()}];try{var r=new window.FormData;r.append("messages",JSON.stringify(d)),r.append("formkey",t),window.navigator.sendBeacon(i,r)}catch(w){var s=new XMLHttpRequest;s.open("POST",i,!0),s.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),
#  s.setRequestHeader("Quora-Formkey",t);var g="messages="+encodeURIComponent(JSON.stringify(d));s.setRequestHeader("Accept","*/*"),s.send(g.replace(/%20/g,"+"))}}}window.wasViewed="visible"===document.visibilityState,window.addEventListener("beforeunload",function(e){logPageBounce("beforeunload")}),window.addEventListener("pagehide",function(e){logPageBounce("pagehide")}),window.addEventListener("visibilitychange",function(e){"hidden"===document.visibilityState?logPageBounce("visibilitychange_hidden"):window.wasViewed=!0});
#  </script><script id="onetrust_auto_block" type="text/javascript">!function(){function t(t){for(var e,r,n,o,a=[],u=0;u<i.length;u++){var f=i[u];if(f.Tag===t){a=f.CategoryId;break}var d=(e=f.Tag,o=n=r=void 0,r=-1!==(o=e).indexOf("http:")?o.replace("http:",""):o.replace("https:",""),-1!==(n=r.indexOf("?"))?r.replace(r.substring(n),""):r);if(t&&(-1!==t.indexOf(d)||-1!==f.Tag.indexOf(t))){a=f.CategoryId;break}}if(!a.length&&c){var m=function(t){var e=document.createElement("a");return e.href=t,t=e.hostname.split("."),-1!==t.indexOf("www")||2<t.length?t.slice(1).join("."):e.hostname}(t);s.some(function(t){return t===m})&&(a=["C0004"])}return a}function e(t){return t&&window.OptanonActiveGroups&&t.every(function(t){return-1!==window.OptanonActiveGroups.indexOf(t)})}function r(t){return-1!==(t.getAttribute("class")||"").indexOf("optanon-category")}function n(t){return t.hasAttribute("data-ot-ignore")}function o(t,e){t=t.join("-");var r=e.getAttribute("class")||"";-1===r.indexOf("optanon-category-"+t)&&(t=a(t,r),e.setAttribute("class",t))}function a(t,e){return("optanon-category-"+t+" "+e).trim();
#  }var i=JSON.parse('[{"Host":"quora.com","Tag":"https://connect.facebook.net/signals/config/1675581722730896","CategoryId":["C0004"]},{"Host":"quora.com","Tag":"https://www.quora.com/ajax/receive_POST","CategoryId":["C0003"]},{"Host":"www.facebook.com","Tag":"https://www.facebook.com/tr/","CategoryId":["C0004"]}]'),c=JSON.parse("true"),s="addthis.com addtoany.com adsrvr.org amazon-adsystem.com bing.com bounceexchange.com bouncex.net criteo.com criteo.net dailymotion.com doubleclick.net everesttech.net facebook.com facebook.net googleadservices.com googlesyndication.com krxd.net liadm.com linkedin.com outbrain.com rubiconproject.com sharethis.com taboola.com twitter.com vimeo.com yahoo.com youtube.com".split(" "),u=["embed","iframe","img","script"];new MutationObserver(function(a){Array.prototype.forEach.call(a,function(a){Array.prototype.forEach.call(a.addedNodes,function(a){var i,c;if(1===a.nodeType&&-1!==u.indexOf(a.tagName.toLowerCase())&&!r(a)&&!n(a))if("script"===a.tagName.toLowerCase()){
#  if((c=t(i=a.src||"")).length){o(c,a),e(c)||(a.type="text/plain");var s=function(t){"text/plain"===a.getAttribute("type")&&t.preventDefault(),a.removeEventListener("beforescriptexecute",s)};a.addEventListener("beforescriptexecute",s)}}else(c=t(i=a.src||"")).length&&(o(c,a),e(c)||(a.removeAttribute("src"),a.setAttribute("data-src",i)))});var i=a.target;if(a.attributeName&&(!r(i)||!n(i)))if("script"===i.nodeName.toLowerCase()){if((f=t(s=i.src||"")).length){o(f,i),e(f)||(i.type="text/plain");var c=function(t){"text/plain"===i.getAttribute("type")&&t.preventDefault(),i.removeEventListener("beforescriptexecute",c)};i.addEventListener("beforescriptexecute",c)}}else if(-1!==u.indexOf(a.target.nodeName.toLowerCase())){var s,f;(f=t(s=i.src||"")).length&&(o(f,i),e(f)||(i.removeAttribute("src"),i.setAttribute("data-src",s)))}})}).observe(document.documentElement,{childList:!0,subtree:!0,attributes:!0,attributeFilter:["src"]});var f=document.createElement;document.createElement=function(){for(var o=[],i=0;i<arguments.length;i++)o[i]=arguments[i];
#  if("script"!==o[0].toLowerCase()&&-1===u.indexOf(o[0].toLowerCase()))return f.bind(document).apply(void 0,o);var c=f.bind(document).apply(void 0,o),s=c.setAttribute.bind(c);return Object.defineProperties(c,{src:{get:function(){return c.getAttribute("src")||""},set:function(i){var f="";return"string"==typeof i?f=i:i instanceof Object&&(f=i.toString()),f=t(f),!f.length||"script"!==o[0].toLowerCase()||r(c)||e(f)||n(c)?!f.length||-1===u.indexOf(o[0].toLowerCase())||r(c)||e(f)||n(c)?s("src",i):(c.removeAttribute("src"),s("data-src",i),i=c.getAttribute("class"),f=f.join("-"),i||(i=a(f,i||""),s("class",i))):(s("type","text/plain"),s("src",i)),!0}},type:{get:function(){return c.getAttribute("type")||""},set:function(o){var a=t(c.src||"");return o=!a.length||r(c)||e(a)||n(c)?o:"text/plain",s("type",o),!0}},"class":{get:function(){return c.getAttribute("class")||""},set:function(o){var i=t(c.src);return!i.length||r(c)||e(i)||n(c)?s("class",o):(o=a(i.join("-"),o),s("class",o)),!0}}}),c.setAttribute=function(t,e,r){
#  "type"!==t&&"src"!==t||r?s(t,e):c[t]=e},c}}();
#  </script><script async="1" id="entryjs" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-45fb25f19e8b12dc.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-d63dccccd7532047.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-85d32558dbb194f2.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack" type="text/javascript"></script><script type="text/javascript">window.executeAfterEntryjsLoaded(() => window.runApp());</script>
#  <script type="application/ld+json">
#          {"@context": "http://schema.org", "@type": "QAPage", "mainEntity": {"@type": "Question", "about": [{"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-1394227-100-lnxbuflwjrfcrgnmlzvedbdnecjbgoaj.jpeg", "name": "Education"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-5066-100-6RWaKqS1GPA0Ai7nLlwZlBkNmWUy9hXw.jpeg", "name": "Online Training"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-6637-100-sswbyptgpctzzgbglnfwgcklwauskdgk.jpeg", "name": "Professional Certifications"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-10154-100-VWO7PH1Qs8dCNOe2yQ5bIwgDG24EIJ2x.jpeg", "name": "E-learning"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-1394227-100-lnxbuflwjrfcrgnmlzvedbdnecjbgoaj.jpeg", "name": "Certifications"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-198323-100-fwpeyfeqcltmyypavbftufczhepevxgi.jpeg", "name": "Coursera"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-227936-100-zbWDbPM7sJuBL3q9unhWTvAQkCxlPEhb.jpeg", "name": "Massive Open Online Courses (MOOCs)"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-227936-100-zbWDbPM7sJuBL3q9unhWTvAQkCxlPEhb.jpeg", "name": "Coursera Courses"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-2344059-100-fpxcsnmwkiyjrmztdrvxodozwsbtecln.jpeg", "name": "E-learning Com"}], "answerCount": 3, "author": {"@type": "Person", "agentInteractionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/ReplyAction", "userInteractionCount": 240}, "image": "https://qph.cf2.quoracdn.net/main-thumb-163115452-100-hyddcfsepxmikrfxyuhrozkkntmnkduy.jpeg", "interactionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/FollowAction", "userInteractionCount": 364}, "name": "Amit Jacobs", "url": "https://www.quora.com/profile/Amit-Jacobs"}, "dateCreated": "2019-08-05T05:18:53.594290+00:00", "dateModified": "2023-01-14T13:59:15.482773+00:00", "hasPart": {"@type": "WebPageElement", "cssSelector": ".content-monetization-wall", "isAccessibleForFree": "False"}, "isAccessibleForFree": "False", "name": "Is it possible to forge a Coursera course completion certificate?", "suggestedAnswer": [{"@type": "Answer", "author": {"@type": "Person", "affiliation": {"@type": "CollegeOrUniversity", "name": "Coursera"}, "agentInteractionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/ReplyAction", "userInteractionCount": 199}, "description": "ONLINE CERTIFICATION Python, Coursera", "hasCredential": {"@type": "EducationalOccupationalCredential", "credentialCategory": "degree", "educationalLevel": "ONLINE CERTIFICATION"}, "image": "https://qph.cf2.quoracdn.net/main-thumb-356153449-100-dszjcvoitzbtzausdjvofujyzzggzgum.jpeg", "interactionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/FollowAction", "userInteractionCount": 310}, "knowsAbout": ["Python"], "name": "Nawlesh", "url": "https://www.quora.com/profile/Nawlesh"}, "dateCreated": "2020-06-09T09:32:43.101530+00:00", "dateModified": "2020-06-09T09:42:29.926200+00:00", "parentItem": {"@type": "Comment", "text": "How do I learn in Coursera for free?", "url": "https://www.quora.com/How-do-I-learn-in-Coursera-for-free"}, "text": "Well, I am a better person to answer this question\u263a\ufe0f, because I have completed so many specialization courses for free and gained a certificate also. COURSERA has charged no money for taking that course.\n\nCoursera is a huge platform where one can learn anything they want from the world\u2019s best instructor and faculty .All those instructors are from the leading institute or they are working professionals. Coursera offers the facility of \u201cfinancial aid\u201d to all those students who can\u2019t afford the price of the course.\n\nHow to avail the financial aid ?Read the below steps-\n\n1 ...
#          </script>
#  <title>Is it possible to forge a Coursera course completion certificate? - Quora</title><link href="https://qsf.cf2.quoracdn.net/-4-images.favicon-new.ico-26-07ecf7cd341b6919.ico" rel="icon"/><meta content="noarchive" name="robots"/><meta content="136609459636" property="fb:app_id"/><meta content="Is it possible to forge a Coursera course completion certificate?" property="og:title"/><meta content="article" property="og:type"/><meta content="Quora" property="og:site_name"/><meta content="https://qph.cf2.quoracdn.net/main-custom-t-1394227-600x315-lnxbuflwjrfcrgnmlzvedbdnecjbgoaj.jpeg" property="og:image"/><meta content="https://www.quora.com/Is-it-possible-to-forge-a-Coursera-course-completion-certificate" property="og:url"/><meta content="Answer (1 of 3): It is not advisable to forge a Coursera course completion certificate. This is considered as a fraud and it could have legal and professional consequences.
#
#  Coursera uses a variety of methods to verify the identity of its students and to ensure the integrity of its course complet..." property="og:description"/><meta content="summary_large_image" name="twitter:card"/><meta content="@Quora" name="twitter:site"/><meta content="https://www.quora.com/Is-it-possible-to-forge-a-Coursera-course-completion-certificate" name="twitter:url"/><meta content="Is it possible to forge a Coursera course completion certificate?" name="twitter:title"/><meta content="Answer (1 of 3): It is not advisable to forge a Coursera course completion certificate. This is considered as a fraud and it could have legal and professional consequences.
#
#  Coursera uses a variety of methods to verify the identity of its students and to ensure the integrity of its course complet..." name="twitter:description"/><meta content="https://qph.cf2.quoracdn.net/main-custom-t-1394227-600x315-lnxbuflwjrfcrgnmlzvedbdnecjbgoaj.jpeg" name="twitter:image"/><meta content="It is not advisable to forge a Coursera course completion certificate. This is considered as a fraud and it could have legal and professional consequences. Coursera uses a variety of methods to verify the identity of its students and to ensure the..." name="description"/><link href="https://www.quora.com/Is-it-possible-to-forge-a-Coursera-course-completion-certificate" rel="canonical"/><meta content="255232486973" property="fb:pages"/><meta content="light" name="twitter:widgets:theme"/></head><body class="q-platform--desktop" style="margin: 0;padding: 0;"><div id="staticError" style="display: none;"><div style='height: 100vh; display: flex; font-size: 15px;background-color: #fff; color: #282829;flex-direction: column; align-items: center; justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'><svg height="24px" viewbox="0 0 24 24" width="24px">
#  <g fill="none" fillrule="evenodd" id="error" stroke="none" transform="translate(3.000000, 3.000000)">
#  <path classname="icon_svg-fill_as_stroke" d="M9,12 C9.55228475,12 10,12.4477153 10,13 C10,13.5522847 9.55228475,14 9,14 C8.44771525,14 8,13.5522847 8,13 C8,12.4477153 8.44771525,12 9,12 Z" fill="#666666" fillrule="nonzero"></path>
#  <path classname="icon_svg-stroke" d="M9,9.5 L9,4.5 L9,9.5 Z M9,18 C4.029,18 0,13.971 0,9 C0,4.029 4.029,0 9,0 C13.971,0 18,4.029 18,9 C18,13.971 13.971,18 9,18 Z" stroke="#666" strokelinecap="round" strokewidth="1.5"></path>
#  </g>
#  </svg><p style="text-align: center; margin-top: 8px; max-width: 60vw;margin-bottom: 16px;">Something went wrong. Wait a moment and try again.</p><button onclick="location.reload();" style='padding: 8px 16px;font-size: 15px; background-color: #2E69FF; color: #fff;border: 0; border-radius: 9999em; appearance: none;cursor:pointer;-webkit-appearance: none;font-family:-apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>Try again</button></div></div><script type="text/javascript">window.addEventListener("load",function(e){window.errorTimer=window.setTimeout(function(){var e=document.getElementById("root");if(e&&e.children&&0===e.children.length&&!window.initialRenderComplete){var t=document.getElementById("loader");t&&t.remove();var n=document.getElementById("staticError");if(n&&n.style&&n.style.display){n.style.display="block";var o=new XMLHttpRequest;o.open("POST","/ajax/log_static_error_state_shown_3RD_PARTY_POST",!0),o.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),o.setRequestHeader("Accept","*/*"),o.send("")}}},1e4)});
#  </script><div class="" id="loader" style='height: calc(100vh - 50px);margin-top: 50px;display: flex;font-size: 15px;background-color: #fff;flex-direction: column;align-items: center;justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif'><div style="position: fixed;top: 0;left: 0;right: 0;height: 50px;background-color: #fff;border-bottom: 1px solid rgb(222, 224, 225);box-shadow: 0 3px 6px rgba(0, 0, 0, 0.04)"></div><style>@keyframes loader-line{0%{transform:translateX(calc(-100% + 3px));opacity:.5}25%,75%{opacity:1}50%{transform:translateX(calc(100% - 3px));opacity:.5}100%{transform:translateX(calc(-100% + 3px));opacity:.5}}@keyframes entrance{0%{transform:scale(.9);opacity:0}100%{transform:scale(1);opacity:1}}@keyframes logo-entrance{100%{fill:#b92b27;opacity:1}}@keyframes logo-entrance-dark{100%{fill:#f52936;opacity:1}}#loader svg{width:48px;height:48px}#loader svg path{fill:#8e9092;opacity:.6;animation:logo-entrance .15s ease-in forwards;animation-delay:1s}#loader.loader-dark svg path{fill:#8e9092;animation-name:logo-entrance-dark}</style><svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27"></path>
#  </svg>
#  <div style="height: 3px;width: 20px;position: relative;border-radius: 1000px;margin-top: 6px;overflow: hidden;animation: entrance .15s ease-in 1s 1 both"><div style="position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0"></div></div></div><script type="text/javascript">window.loaderTimer=setTimeout(function(){var e=document.getElementById("loader");e&&e.style&&e.style.display&&(e.style.display="flex")},100);
#  </script><div id="root"></div><noscript>Please enable Javascript and refresh the page to continue</noscript><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "q", "controller": "question", "pageOid": 53949508, "getPageTypeOfRefererUrl": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "103c72edb0cf6b27c13834282aedad3e901de3ce", "isCanaryRevision": false, "debugToolsEnabled": false, "postkey": "4719bd7505ecc55354462adba2e04342", "buildNumber": 0, "broadcastId": "main-w-chan68-8888-react_afvxlnopeppkuxmz-LvGS", "broadcastDisabled": false, "tchannelData": null, "viewerUniversalUid": null, "viewerMemberUid": null, "isMemberQuoraEmployee": false, "shouldReportE2E": false, "shouldReportReactLoadableE2E": false, "cdn": "cloudflare", "request_id": "2855c4a2f99f4fbcb726b0e3bf8a1b7d", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "new_progressive_page_wrapper_logged_in": null, "new_progressive_page_wrapper_logged_out": null, "app_download_wall_holdout": null, "remove_more_stories_from_digest_ad": null, "standard_ad_copy_logged_in": null, "standard_ad_copy_logged_out": null, "subscriptions_logged_in_holdout": null, "subscriptions_quora_plus_corner_badge_2": null, "share_answer_skip_redirect": null, "desktop_home_rr_live_stats": null, "gpt_3_5_machine_answers_logged_in": null, "gpt_3_5_machine_answers_logged_out": null, "altered_credential_length_expand_logged_in": null, "altered_credential_length_expand_logged_out": null, "qp_ra_grouping_4_logged_in": null, "qp_ra_grouping_4_logged_out": null, "logged_out_home_feed_i18n": null, "home_page_jp_right_rail_poe_promotion_desktop": null, "question_page_llm_answer_less_prominent_logged_in": null, "question_page_llm_answer_less_prominent_logged_out": null}, "features": {"SmartQuotesEnabled": true, "DisabledEditorCommands": [], "PreventActionBarOverflow": false, "StyleLineHeightFeature": 1, "StyleFontFamilyFeature": 1, "DefaultContentBidiDirectionIsRTL": false, "AllowColorModesInInterface": false, "UseAllCapsInInterface": true, "SpammerCaptchaChallengeCondition": false, "TribesNameCharacterLimit": 50, "TribesDescriptionCharacterLimit": 80, "TribesRulesCharacterLimit": 1600, "CommentAdsEnabled": true, "LoggedOutHomeFeedEnabled": false, "TribeEarningsProgramFeature": true, "PaidSubscriptionEnabledForProducer": true, "ConsumerDirectSubscriptions": true, "ConsumerBundleSubscriptions": true, "ShowPaywallsToConsumers": true, "EnableSubscriptionsDebugMode": false, "EnableContentDemonetizationUpdate": true, "IsEligibleForINPricing": false, "DisableBundlePricingTest": false, "QuestionPagedListExpandableListEnabled": false, "QuestionPagedListAnswerGroupingUXEnabled": false, "MachineAnswerRenderedAsStoryCard": false, "ShowPrivacyChoicesLink": false, "ShowCookieWarning": true, "NuxFollowTopicsLowerRequirements": true, "UseExtraAnimationInInterface": true, "TimeSeriesStatsNumBins": 30}, "gates": {"enable_quora_plus_business_tax_id_collection": false, "test_ad_id": null, "ads_show_message_banner": {"learn_more_link": "", "message": ""}, "ads_power_user_accounts": [527765581395999, 527765581347597, 527765581430418, 527765581357948, 527765581506382, 45, 527765581332623, 527765581381996, 527765581357948, 527765581336168, 527765581680251, 527765581357110, 527765581966634, 527765581922413, 527765581395999, 527765582099262, 527765581883762, 527765581375737, 527765581378571, 527765581970184, 527765582305394, 123, 527765581495867, 11, 527765582354676, 527765582133478, 527765582172035, 527765582134968, 527765582172032, 527765582134971, 527765582172051, 527765582134987, 527765582172064, 527765582251231, 527765582251235, 527765582251225, 527765582251226, 527765582134978, 527765582172075, 527765582251215, 527765582251217, 527765581332623, 527765582288011, 124, 527765581473960, 527765582360433, 527765582312602, 527765582609130, 527765582688102, 527765582688100, 5277655827 ...
#                      window.executeAfterEntryjsLoaded(
#                          () => window.setTimingData({"server_time":832.763,"total_worker_time":5044.934,"window_id":"react_afvxlnopeppkuxmz","page":832.763,"request":841.842}));
#
#                      window.executeAfterEntryjsLoaded(
#                          () => window.reportPageSpeedData({"standard":{}}));
#
#                  </script></body></html>,
#  <head prefix="og: http://ogp.me/ns#"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-45fb25f19e8b12dc.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-d63dccccd7532047.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-85d32558dbb194f2.webpack" rel="preload"/><link as="script" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack" rel="preload"/><link as="style" href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-5cf6a3e5274bdb4b.webpack" rel="preload"/><link href="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-5cf6a3e5274bdb4b.webpack" id="ans-frontend-main-css" rel="stylesheet" type="text/css"/><script type="text/javascript">function reportToAndroid(){if(0!==assetErrs.length){var e=window.QuoraAndroid;e&&e.reportBrowserAssetLoadErrors&&e.reportBrowserAssetLoadErrors(assetErrs)}}var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),r=new XMLHttpRequest;r.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),r.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),r.setRequestHeader("Accept","*/*"),r.send(e.replace(/%20/g,"+"))}},0),setTimeout(function(){reportToAndroid()},500)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};
#  </script><script id="entryjs_wrapper" type="text/javascript">
#          window.__entryChunkLoaded = false;
#          window.__onEntryLoaded = [];
#          window.executeAfterEntryjsLoaded = function (callback) {
#              if (window.__entryChunkLoaded) {
#                  callback();
#              } else {
#                  window.__onEntryLoaded.push(callback);
#              }
#          }
#      </script><script type="text/javascript">window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"0":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-0-27-8f1f52608d2109b5.webpack","common":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack","common-LoggedOut":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack","common-Mweb":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-Mweb-27-a2a9baed98b578b2.webpack","common-NativeApp":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-NativeApp-27-5ac0f4987a77a6e9.webpack","common-secondary":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-secondary-27-5d3f8a77b917c3f6.webpack","component-ActivationDeckInner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ActivationDeckInner-27-108638bff8c6fc4a.webpack","component-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack","component-AdCTABanner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-fc5f333bd1dbb044.webpack","component-AdminTools-profile":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-8482e48a7b12f267.webpack","component-AnnouncementBundle":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnnouncementBundle-27-93eeec7919d4d58a.webpack","component-AnswerFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerFooter-27-3930dae346f85416.webpack","component-AnswerPageFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-7083d7cb98258866.webpack","component-CaptchaPopper":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CaptchaPopper-27-9abe5b6edbdac191.webpack","component-CollapseAnswerSection":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CollapseAnswerSection-27-9b5e942a1b461e1c.webpack","component-CommentAd":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CommentAd-27-410023ea1055f83a.webpack","component-Comments":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-4611281ba67142a5.webpack","component-FeedSwitcher":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FeedSwitcher-27-e01ab61d19a895f4.webpack","component-FirstFeedScrollPrompt":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FirstFeedScrollPrompt-27-22169656b2cee358.webpack","component-GenericRightRail-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-GenericRightRail-Ad-27-c1feaad37682332d.webpack","component-Hovercards":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-849647e7e4f247bc.webpack","component-ImageViewer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ImageViewer-27-75f2fc0682e7421f.webpack","component-LightweightSurvey":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LightweightSurvey-27-a66e1c8cee192e1d.webpack","component-LiveStatsBundle":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LiveStatsBundle-27-a089ab62a894065a.webpack","component-LoggedOutFeed":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LoggedOutFeed-27-f31f207a3c91f459.webpack","component-Login":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Login-27-ea4f62d26c121889.webpack","component-MobileLookup":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-956821c6311b13ad.webpack","component-Modals-AdsConsumer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-6a28ee082ea21a21.webpack","component-Modals-AdsManager":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-f9a883c2ecd8eed3.webpack","component-Modals-AskQuestion":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-2630df9808f9e392.webpac ...
#  var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
#  window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-QuestionPageLoadable","component-Ad","component-QuestionPage","common-LoggedOut"]);</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "7d51d25ea07a98ba1a319b9b93cb8365", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "isMobileAppPrefetched": false, "topLevelNid": 0, "react_console_log_perf_info": false, "subdomainSuffix": "quora.com", "windowId": "react_afvxlnopeppkuxmz", "rootClsKey": "QuestionPage", "rootQueryVariables": {"questionSlug": "Is-it-possible-to-forge-a-Coursera-course-completion-certificate", "questionSlugEncoded": "Is-it-possible-to-forge-a-Coursera-course-completion-certificate", "redirectedQid": 0, "topAid": null, "first": 50, "forceScoreVersion": null}, "rootProps": {}, "pageWrapperQueryVariables": {}, "inlineQueryHashes": {"27a81ba144b4201b299bc86442d67c6bb37896ff0e163465e59b90ee95b98604": true, "3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b": true, "2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083": true}, "pageShellInfo": null, "shouldServerRender": false, "hasIndicator": true, "isServiceWorkerConstructed": false};</script><script type="text/javascript">function getLoggingUrl(){var e="/ajax/page_bounce_POST";return"quora.com"==window.ansFrontendGlobals.earlySettings.subdomainSuffix?"https://log.quora.com/ajax/page_bounce_POST":e}function logPageBounce(e){if(window.isReactPage&&!window.reportedPageLoadBounce&&!window.ansFrontendGlobals.earlySettings.isMobileAppPrefetched&&!window.ansFrontendGlobals.earlySettings.isPrefetchedPage){window.reportedPageLoadBounce=!0;var n=window.ansFrontendGlobals.earlySettings.windowId,o={url:window.location.href,windowId:n,wasViewed:window.wasViewed};if(window.performance&&window.performance.timing){var a=window.performance.timing.navigationStart;a&&(o.unloadTime=Date.now()-a,o.cause=e)}var i=getLoggingUrl(),t=window.ansFrontendGlobals.earlySettings.formkey,d=[{category:"unload_before_page_ready",data:o,time:1e3*Date.now()}];try{var r=new window.FormData;r.append("messages",JSON.stringify(d)),r.append("formkey",t),window.navigator.sendBeacon(i,r)}catch(w){var s=new XMLHttpRequest;s.open("POST",i,!0),s.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),
#  s.setRequestHeader("Quora-Formkey",t);var g="messages="+encodeURIComponent(JSON.stringify(d));s.setRequestHeader("Accept","*/*"),s.send(g.replace(/%20/g,"+"))}}}window.wasViewed="visible"===document.visibilityState,window.addEventListener("beforeunload",function(e){logPageBounce("beforeunload")}),window.addEventListener("pagehide",function(e){logPageBounce("pagehide")}),window.addEventListener("visibilitychange",function(e){"hidden"===document.visibilityState?logPageBounce("visibilitychange_hidden"):window.wasViewed=!0});
#  </script><script id="onetrust_auto_block" type="text/javascript">!function(){function t(t){for(var e,r,n,o,a=[],u=0;u<i.length;u++){var f=i[u];if(f.Tag===t){a=f.CategoryId;break}var d=(e=f.Tag,o=n=r=void 0,r=-1!==(o=e).indexOf("http:")?o.replace("http:",""):o.replace("https:",""),-1!==(n=r.indexOf("?"))?r.replace(r.substring(n),""):r);if(t&&(-1!==t.indexOf(d)||-1!==f.Tag.indexOf(t))){a=f.CategoryId;break}}if(!a.length&&c){var m=function(t){var e=document.createElement("a");return e.href=t,t=e.hostname.split("."),-1!==t.indexOf("www")||2<t.length?t.slice(1).join("."):e.hostname}(t);s.some(function(t){return t===m})&&(a=["C0004"])}return a}function e(t){return t&&window.OptanonActiveGroups&&t.every(function(t){return-1!==window.OptanonActiveGroups.indexOf(t)})}function r(t){return-1!==(t.getAttribute("class")||"").indexOf("optanon-category")}function n(t){return t.hasAttribute("data-ot-ignore")}function o(t,e){t=t.join("-");var r=e.getAttribute("class")||"";-1===r.indexOf("optanon-category-"+t)&&(t=a(t,r),e.setAttribute("class",t))}function a(t,e){return("optanon-category-"+t+" "+e).trim();
#  }var i=JSON.parse('[{"Host":"quora.com","Tag":"https://connect.facebook.net/signals/config/1675581722730896","CategoryId":["C0004"]},{"Host":"quora.com","Tag":"https://www.quora.com/ajax/receive_POST","CategoryId":["C0003"]},{"Host":"www.facebook.com","Tag":"https://www.facebook.com/tr/","CategoryId":["C0004"]}]'),c=JSON.parse("true"),s="addthis.com addtoany.com adsrvr.org amazon-adsystem.com bing.com bounceexchange.com bouncex.net criteo.com criteo.net dailymotion.com doubleclick.net everesttech.net facebook.com facebook.net googleadservices.com googlesyndication.com krxd.net liadm.com linkedin.com outbrain.com rubiconproject.com sharethis.com taboola.com twitter.com vimeo.com yahoo.com youtube.com".split(" "),u=["embed","iframe","img","script"];new MutationObserver(function(a){Array.prototype.forEach.call(a,function(a){Array.prototype.forEach.call(a.addedNodes,function(a){var i,c;if(1===a.nodeType&&-1!==u.indexOf(a.tagName.toLowerCase())&&!r(a)&&!n(a))if("script"===a.tagName.toLowerCase()){
#  if((c=t(i=a.src||"")).length){o(c,a),e(c)||(a.type="text/plain");var s=function(t){"text/plain"===a.getAttribute("type")&&t.preventDefault(),a.removeEventListener("beforescriptexecute",s)};a.addEventListener("beforescriptexecute",s)}}else(c=t(i=a.src||"")).length&&(o(c,a),e(c)||(a.removeAttribute("src"),a.setAttribute("data-src",i)))});var i=a.target;if(a.attributeName&&(!r(i)||!n(i)))if("script"===i.nodeName.toLowerCase()){if((f=t(s=i.src||"")).length){o(f,i),e(f)||(i.type="text/plain");var c=function(t){"text/plain"===i.getAttribute("type")&&t.preventDefault(),i.removeEventListener("beforescriptexecute",c)};i.addEventListener("beforescriptexecute",c)}}else if(-1!==u.indexOf(a.target.nodeName.toLowerCase())){var s,f;(f=t(s=i.src||"")).length&&(o(f,i),e(f)||(i.removeAttribute("src"),i.setAttribute("data-src",s)))}})}).observe(document.documentElement,{childList:!0,subtree:!0,attributes:!0,attributeFilter:["src"]});var f=document.createElement;document.createElement=function(){for(var o=[],i=0;i<arguments.length;i++)o[i]=arguments[i];
#  if("script"!==o[0].toLowerCase()&&-1===u.indexOf(o[0].toLowerCase()))return f.bind(document).apply(void 0,o);var c=f.bind(document).apply(void 0,o),s=c.setAttribute.bind(c);return Object.defineProperties(c,{src:{get:function(){return c.getAttribute("src")||""},set:function(i){var f="";return"string"==typeof i?f=i:i instanceof Object&&(f=i.toString()),f=t(f),!f.length||"script"!==o[0].toLowerCase()||r(c)||e(f)||n(c)?!f.length||-1===u.indexOf(o[0].toLowerCase())||r(c)||e(f)||n(c)?s("src",i):(c.removeAttribute("src"),s("data-src",i),i=c.getAttribute("class"),f=f.join("-"),i||(i=a(f,i||""),s("class",i))):(s("type","text/plain"),s("src",i)),!0}},type:{get:function(){return c.getAttribute("type")||""},set:function(o){var a=t(c.src||"");return o=!a.length||r(c)||e(a)||n(c)?o:"text/plain",s("type",o),!0}},"class":{get:function(){return c.getAttribute("class")||""},set:function(o){var i=t(c.src);return!i.length||r(c)||e(i)||n(c)?s("class",o):(o=a(i.join("-"),o),s("class",o)),!0}}}),c.setAttribute=function(t,e,r){
#  "type"!==t&&"src"!==t||r?s(t,e):c[t]=e},c}}();
#  </script><script async="1" id="entryjs" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-45fb25f19e8b12dc.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-999c0d715f6dd6cd.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-d63dccccd7532047.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-8fe885d815cc4c94.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-85d32558dbb194f2.webpack" type="text/javascript"></script><script async="1" onerror="addAssetErr(this.src)" src="https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-9813ba6f144d098f.webpack" type="text/javascript"></script><script type="text/javascript">window.executeAfterEntryjsLoaded(() => window.runApp());</script>
#  <script type="application/ld+json">
# ...
#  <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#  <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27"></path>
#  </svg>,
#  <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27"></path>,
#  <div style="height: 3px;width: 20px;position: relative;border-radius: 1000px;margin-top: 6px;overflow: hidden;animation: entrance .15s ease-in 1s 1 both"><div style="position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0"></div></div>,
#  <div style="position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0"></div>,
#  <script type="text/javascript">window.loaderTimer=setTimeout(function(){var e=document.getElementById("loader");e&&e.style&&e.style.display&&(e.style.display="flex")},100);
#  </script>,
#  <div id="root"></div>,
#  <noscript>Please enable Javascript and refresh the page to continue</noscript>,
#  <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "q", "controller": "question", "pageOid": 53949508, "getPageTypeOfRefererUrl": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "103c72edb0cf6b27c13834282aedad3e901de3ce", "isCanaryRevision": false, "debugToolsEnabled": false, "postkey": "4719bd7505ecc55354462adba2e04342", "buildNumber": 0, "broadcastId": "main-w-chan68-8888-react_afvxlnopeppkuxmz-LvGS", "broadcastDisabled": false, "tchannelData": null, "viewerUniversalUid": null, "viewerMemberUid": null, "isMemberQuoraEmployee": false, "shouldReportE2E": false, "shouldReportReactLoadableE2E": false, "cdn": "cloudflare", "request_id": "2855c4a2f99f4fbcb726b0e3bf8a1b7d", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "new_progressive_page_wrapper_logged_in": null, "new_progressive_page_wrapper_logged_out": null, "app_download_wall_holdout": null, "remove_more_stories_from_digest_ad": null, "standard_ad_copy_logged_in": null, "standard_ad_copy_logged_out": null, "subscriptions_logged_in_holdout": null, "subscriptions_quora_plus_corner_badge_2": null, "share_answer_skip_redirect": null, "desktop_home_rr_live_stats": null, "gpt_3_5_machine_answers_logged_in": null, "gpt_3_5_machine_answers_logged_out": null, "altered_credential_length_expand_logged_in": null, "altered_credential_length_expand_logged_out": null, "qp_ra_grouping_4_logged_in": null, "qp_ra_grouping_4_logged_out": null, "logged_out_home_feed_i18n": null, "home_page_jp_right_rail_poe_promotion_desktop": null, "question_page_llm_answer_less_prominent_logged_in": null, "question_page_llm_answer_less_prominent_logged_out": null}, "features": {"SmartQuotesEnabled": true, "DisabledEditorCommands": [], "PreventActionBarOverflow": false, "StyleLineHeightFeature": 1, "StyleFontFamilyFeature": 1, "DefaultContentBidiDirectionIsRTL": false, "AllowColorModesInInterface": false, "UseAllCapsInInterface": true, "SpammerCaptchaChallengeCondition": false, "TribesNameCharacterLimit": 50, "TribesDescriptionCharacterLimit": 80, "TribesRulesCharacterLimit": 1600, "CommentAdsEnabled": true, "LoggedOutHomeFeedEnabled": false, "TribeEarningsProgramFeature": true, "PaidSubscriptionEnabledForProducer": true, "ConsumerDirectSubscriptions": true, "ConsumerBundleSubscriptions": true, "ShowPaywallsToConsumers": true, "EnableSubscriptionsDebugMode": false, "EnableContentDemonetizationUpdate": true, "IsEligibleForINPricing": false, "DisableBundlePricingTest": false, "QuestionPagedListExpandableListEnabled": false, "QuestionPagedListAnswerGroupingUXEnabled": false, "MachineAnswerRenderedAsStoryCard": false, "ShowPrivacyChoicesLink": false, "ShowCookieWarning": true, "NuxFollowTopicsLowerRequirements": true, "UseExtraAnimationInInterface": true, "TimeSeriesStatsNumBins": 30}, "gates": {"enable_quora_plus_business_tax_id_collection": false, "test_ad_id": null, "ads_show_message_banner": {"learn_more_link": "", "message": ""}, "ads_power_user_accounts": [527765581395999, 527765581347597, 527765581430418, 527765581357948, 527765581506382, 45, 527765581332623, 527765581381996, 527765581357948, 527765581336168, 527765581680251, 527765581357110, 527765581966634, 527765581922413, 527765581395999, 527765582099262, 527765581883762, 527765581375737, 527765581378571, 527765581970184, 527765582305394, 123, 527765581495867, 11, 527765582354676, 527765582133478, 527765582172035, 527765582134968, 527765582172032, 527765582134971, 527765582172051, 527765582134987, 527765582172064, 527765582251231, 527765582251235, 527765582251225, 527765582251226, 527765582134978, 527765582172075, 527765582251215, 527765582251217, 527765581332623, 527765582288011, 124, 527765581473960, 527765582360433, 527765582312602, 527765582609130, 527765582688102, 527765582688100, 527765582705383, 527765582688105, 527765582705347, 527765582688108, 527765582651119, 527765582547448, 527765582705362] ...
#  <script type="text/javascript">window.executeAfterEntryjsLoaded(() => window.installSettings());</script>,
#  <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendMarkCheckpoint ? window.ansFrontendMarkCheckpoint('timing-PageLoadablePageWrapperQuery1-end') : window.ansFrontendCheckpoints = window.ansFrontendCheckpoints ? {...window.ansFrontendCheckpoints, 'timing-PageLoadablePageWrapperQuery1-end': Date.now()} : {'timing-PageLoadablePageWrapperQuery1-end': Date.now()};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b"] = window.ansFrontendGlobals.data.inlineQueryResults.results["3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b"].push("{\"data\":{\"viewer\":{\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"showGoToFeedGrowl\":false,\"showGoToFeedGrowlBadge\":false,\"followingTabBadgeCount\":0,\"writeNavBadgeCount\":0,\"profileNavBadgeCount\":0,\"tribeNavBadgeCount\":0,\"inboxCount\":0,\"notificationNavBadgeCount\":0,\"user\":null,\"silosBadgeCount\":\"{}\",\"network\":{\"nid\":0,\"id\":\"TmV0d29yazow\"},\"memberNetworks\":[],\"consumerBundleSubscription\":null,\"isAdminMode\":false,\"mwebBannerToShow\":null,\"canSeeAds\":true,\"isGdprApplicable\":false,\"signupId\":\"3IXBgt9V0h_KnRV4I_r4MQ==_1702474260058207\",\"facebookAuthNonce\":null},\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"loginShouldShowLogoutAll\":false},\"extensions\":{\"is_final\":true}}");window.ansFrontendGlobals.data.inlineQueryResults.next["3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b"] && window.ansFrontendGlobals.data.inlineQueryResults.next["3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b"]();</script>,
#  <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendMarkCheckpoint ? window.ansFrontendMarkCheckpoint('timing-PageFlowsLoaderQuery1-end') : window.ansFrontendCheckpoints = window.ansFrontendCheckpoints ? {...window.ansFrontendCheckpoints, 'timing-PageFlowsLoaderQuery1-end': Date.now()} : {'timing-PageFlowsLoaderQuery1-end': Date.now()};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083"] = window.ansFrontendGlobals.data.inlineQueryResults.results["2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083"].push("{\"data\":{\"viewer\":{\"bannerJoinPromptNetwork\":null,\"shouldShowNonMemberJoinNetworkModal\":false,\"googleOneTapEnabled\":true,\"network\":{\"canonicalSubdomain\":\"www\",\"id\":\"TmV0d29yazow\"},\"id\":\"Vmlld2VyQDA6MA==\",\"__typename\":\"Viewer\",\"isUniversalLoggedIn\":false,\"notificationNavBadgeCount\":0,\"inboxCount\":0},\"network\":{\"id\":\"TmV0d29yazow\",\"__typename\":\"Network\"},\"activationWall\":null,\"actionBasedWall\":null,\"viewInAppLink\":{\"id\":\"Vmlld0luQXBwTGlua0AwOjA=\"},\"facebookPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"facebookPuaViewer\":{\"uid\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"googlePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"keyweePuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"twitterPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaPixel\":{\"awinAwc\":null,\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"awinPuaViewer\":{\"uid\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"quoraPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"snapPuaViewer\":{\"primaryEmail\":null,\"id\":\"Vmlld2VyQDA6MA==\"},\"tikTokPuaPixel\":{\"eventsToFire\":[],\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"liveRampPixel\":{\"liverampHash\":null,\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"},\"linkedInPixel\":{\"linkedinHash\":null,\"id\":\"VGhpcmRQYXJ0eUFkUGl4ZWxAMDow\"}},\"extensions\":{\"is_final\":true}}");window.ansFrontendGlobals.data.inlineQueryResults.next["2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083"] && window.ansFrontendGlobals.data.inlineQueryResults.next["2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083"]();</script>,
#  <script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.data = window.ansFrontendGlobals.data || {};window.ansFrontendMarkCheckpoint ? window.ansFrontendMarkCheckpoint('timing-QuestionPageLoadableQuery1-end') : window.ansFrontendCheckpoints = window.ansFrontendCheckpoints ? {...window.ansFrontendCheckpoints, 'timing-QuestionPageLoadableQuery1-end': Date.now()} : {'timing-QuestionPageLoadableQuery1-end': Date.now()};window.ansFrontendGlobals.data.inlineQueryResults = window.ansFrontendGlobals.data.inlineQueryResults || {};window.ansFrontendGlobals.data.inlineQueryResults.results = window.ansFrontendGlobals.data.inlineQueryResults.results || {};window.ansFrontendGlobals.data.inlineQueryResults.next = window.ansFrontendGlobals.data.inlineQueryResults.next || {};window.ansFrontendGlobals.data.inlineQueryResults.results["27a81ba144b4201b299bc86442d67c6bb37896ff0e163465e59b90ee95b98604"] = window.ansFrontendGlobals.data.inlineQueryResults.results["27a81ba144b4201b299bc86442d67c6bb37896ff0e163465e59b90ee95b98604"] || [];window.ansFrontendGlobals.data.inlineQueryResults.results["27a81ba144b4201b299bc86442d67c6bb37896ff0e163465e59b90ee95b98604"].push("{\"data\":{\"question\":{\"pagedListDataConnection\":{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RDb25uZWN0aW9uQDA6NTM5NDk1MDg=\",\"__typename\":\"QuestionPagedListConnection\",\"adsData\":\"{\\\"answer_intervals\\\": [], \\\"ads\\\": []}\",\"pageInfo\":{\"hasNextPage\":false,\"endCursor\":\"37\"},\"edges\":[{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjA=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"id\":\"UXVlc3Rpb25BZEl0ZW1AMDphZDpOb25lOmRjODQ5ZDNhLWU3MDUtNDNiNy05MWE1LWMwOWI0Yzg5ZDAxZg==\",\"__typename\":\"QuestionAdItem\",\"__isQuestionPagedListItem\":\"QuestionAdItem\",\"adLocation\":\"top_slot_question\",\"ad\":null},\"cursor\":\"0\"},{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjE=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"id\":\"UXVlc3Rpb25BbnN3ZXJIZWFkZXJJdGVtQDA6NTM5NDk1MDg6YW5zd2VySGVhZGVy\",\"__typename\":\"QuestionAnswerHeaderItem\",\"__isQuestionPagedListItem\":\"QuestionAnswerHeaderItem\",\"numAnswers\":3,\"numMachineAnswers\":1,\"question\":{\"id\":\"UXVlc3Rpb25AMDo1Mzk0OTUwOA==\",\"__typename\":\"Question\",\"qid\":53949508,\"questionPageClusterVariant\":\"variant\",\"mixRankedAnswersCount\":33}},\"cursor\":\"1\"},{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjI=\",\"__typename\":\"QuestionPagedListEdge\",\"node\":{\"id\":\"UXVlc3Rpb25NYWNoaW5lQW5zd2VySXRlbUAwOjUzOTQ5NTA4OnF1ZXN0aW9uX21hY2hpbmVfYW5zd2VyOjE0Nzc3NDM2NDU3NDUxNzk=\",\"__typename\":\"QuestionMachineAnswerItem\",\"__isQuestionPagedListItem\":\"QuestionMachineAnswerItem\",\"answer\":{\"contentPlaintext\":\"It is not ethical or legal to forge a Coursera course completion certificate. Additionally, doing so could result in serious consequences, such as being expelled from an educational institution or losing your job. It's important to always be honest and truthful about your qualifications and accomplishments. If you're looking to improve your skills and build your resume, there are many legitimate ways to take online courses and earn certifications.\",\"author\":{\"uid\":2089682278,\"id\":\"VXNlckAwOjIwODk2ODIyNzg=\",\"__typename\":\"User\",\"isAnon\":false,\"profileImageUrl\":\"https://qph.cf2.quoracdn.net/main-thumb-2089682278-200-ucpviyzsuycokhosogcjsatkbzaocmpg.jpeg\",\"isVerified\":false,\"businessStatus\":null,\"consumerBundleActive\":false,\"isMachineAnswerBot\":true,\"profileUrl\":\"/profile/Sage-1836\",\"useTranslatedName\":true,\"names\":[{\"__typename\":\"UserName\",\"id\":\"VXNlck5hbWU6MjA4OTY4MjI3ODpMQVRO\",\"reverseOrder\":false,\"givenName\":\"Sage\",\"familyName\":\"\",\"scriptCode\":\"LATN\"}],\"adminNames\":[]},\"aid\":1477743645745179,\"id\":\"QW5zd2VyQDA6MTQ3Nzc0MzY0NTc0NTE3OQ==\"},\"question\":{\"id\":\"UXVlc3Rpb25AMDo1Mzk0OTUwOA==\"}},\"cursor\":\"2\"},{\"id\":\"UXVlc3Rpb25QYWdlZExpc3RFZGdlOjM=\",\"__typename\":\"QuestionPagedListEdge\", ...
#  <script type="text/javascript">
#                      window.executeAfterEntryjsLoaded(
#                          () => window.setTimingData({"server_time":832.763,"total_worker_time":5044.934,"window_id":"react_afvxlnopeppkuxmz","page":832.763,"request":841.842}));
#
#                      window.executeAfterEntryjsLoaded(
#                          () => window.reportPageSpeedData({"standard":{}}));
#
#                  </script>]
